# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("ETL-PROJECT").getOrCreate()

# %%
df = spark.createDataFrame([{"mesaj" : "working" , "hey" : 15}])

# %%
df.show()
# Out:
# +---+-------+
# |hey|  mesaj|
# +---+-------+
# | 15|working|
# +---+-------+
